# %%
# %matplotlib widget
# %matplotlib ipympl
# from ipywidgets import *

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from scipy.ndimage import gaussian_filter

from __future__ import print_function
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.patches as patches
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle
import matplotlib.colors as colors
import matplotlib.cm as cmx
from mpl_toolkits.axes_grid1 import make_axes_locatable
from PIL import Image
from tqdm.notebook import trange, tqdm, tnrange
import time
from datetime import datetime

import math
import glob
import numpy as np


import itertools
import os.path
import os
import sys
from skimage.io import imread
import cv2

import pandas as pd

import imageio
from scipy.signal import savgol_filter
# import pytesseract 

from scipy.signal import find_peaks
matplotlib.rcParams.update({'font.size': 14})
plt.rcParams["font.family"] = "arial"


import SimpleITK as sitk
import imageio
# Out:
# <style>.container { width:100% !important; }</style>

# %%
## Import functions
PathToFunctions = '/Users/iracicot/Documents/GitHub/HySE_HypercubeFunctions/'
sys.path.append(PathToFunctions)
from HySE_HypercubeFunctions import *

## Indicate which wavelengths were used (Panel4, Panel2), in nm
SavingPath = '/Users/iracicot/Library/CloudStorage/OneDrive-UniversityofCambridge/Data/PoM/EndoscopeVideo/20240529/'
Wavelengths_list = np.array([566,494,590,518,614,542,638, 578,506,602,530,626,554,650])

## Locate the data to analyse
# Name = 'Hand_Moving'
# Name = 'Flat'
Name = 'Columns'
DataPath = SavingPath
vidPath = DataPath+Name+'.mpg'

CropImDimensions = [166,680, 42,520] ## Dazzle, PoM

# %%
## Find the positions of each wavelengths in the data trace
## Start with Help=True to have a list and descriptions of all the
## parameters to play with, and then with PlotGradient=True
## to help optimising

# Help()
## This dataset only has 14 wavelengths because one of the FSKs was off
##
EdgePos = FindHypercube(vidPath, Wavelengths_list, PlotGradient=True, CropImDimensions=[166,680, 42,520], PeakHeight=0.08, Ncolours=7)
# Out:
# Add 'Help=True' in input for a list and description of all optional parameters
# Max plateay size set to default of 40
# Min long dark size set to default of 90
# Expected plateau size set to default 45
# ATTENTION: ReturnPeaks is set to True. Be careful, the output will have three elements!
# Only importing the trace of the data
# Cropping Image
# Cropping image: x [166 : 680],y [42, 520]
# No window length or polyorder input. Setting to 6, 1
# Setting peak height to 0.08
# No peak distance input, setting it to default 14
#
# No sweep found. Set PlotGradient to True and play with parameters improve detection
#    To adjust smoothing: window_length, polyorder
#    To adjust edge detection: peak_height, peak_distance
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(test.shape)
plt.close()
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))
# ax.imshow(test[100,:,:], cmap='gray') ## ,vmin=0, vmax=5
ax.plot(test)
plt.show()

# %%
print(Peaks)
# Out:
# [  51   96  141  187  231  279  324  373  594  639  684  729  778  819
#   864  913  999 1044 1089 1138 1179 1224 1269 1318 1539 1584 1629 1674
#  1719 1764 1809 1858 1944 1989 2034 2079 2124 2172 2217 2266 2487 2532
#  2577 2622 2667 2712 2757 2806 2892 2937 2982 3031 3072 3117 3162 3211
#  3432 3477 3522 3567 3612 3661 3702 3751 3837 3882 3927 3972 4017 4065
#  4110 4156 4380 4425 4470 4515 4560 4605 4650 4699 4785 4830 4875 4924
#  4965 5010 5055 5104]

# %%
print(Peaks_dist)
# Out:
# [[  51   45]
#  [  96   45]
#  [ 141   46]
#  [ 187   44]
#  [ 231   48]
#  [ 279   45]
#  [ 324   49]
#  [ 373  221]
#  [ 594   45]
#  [ 639   45]
#  [ 684   45]
#  [ 729   49]
#  [ 778   41]
#  [ 819   45]
#  [ 864   49]
#  [ 913   86]
#  [ 999   45]
#  [1044   45]
#  [1089   49]
#  [1138   41]
#  [1179   45]
#  [1224   45]
#  [1269   49]
#  [1318  221]
#  [1539   45]
#  [1584   45]
#  [1629   45]
#  [1674   45]
#  [1719   45]
#  [1764   45]
#  [1809   49]
#  [1858   86]
#  [1944   45]
#  [1989   45]
#  [2034   45]
#  [2079   45]
#  [2124   48]
#  [2172   45]
#  [2217   49]
#  [2266  221]
#  [2487   45]
#  [2532   45]
#  [2577   45]
#  [2622   45]
#  [2667   45]
#  [2712   45]
#  [2757   49]
#  [2806   86]
#  [2892   45]
#  [2937   45]
#  [2982   49]
#  [3031   41]
#  [3072   45]
#  [3117   45]
#  [3162   49]
#  [3211  221]
#  [3432   45]
#  [3477   45]
#  [3522   45]
#  [3567   45]
#  [3612   49]
#  [3661   41]
#  [3702   49]
#  [3751   86]
#  [3837   45]
#  [3882   45]
#  [3927   45]
#  [3972   45]
#  [4017   48]
#  [4065   45]
#  [4110   46]
#  [4156  224]
#  [4380   45]
#  [4425   45]
#  [4470   45]
#  [4515   45]
#  [4560   45]
#  [4605   45]
#  [4650   49]
#  [4699   86]
#  [4785   45]
#  [4830   45]
#  [4875   49]
#  [4924   41]
#  [4965   45]
#  [5010   45]
#  [5055   49]]
